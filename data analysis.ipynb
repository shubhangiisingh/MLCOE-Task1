# %% [markdown]
# # DATA ANALYSIS :https://docs.google.com/spreadsheets/d/1jpOdtGqOci9WPK7pwVN0MMmw1UOjH7ZN3zNcaBfTKug/edit?usp=sharing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('data anay.csv')

# %%
df  # data frame
# Out:
#       Customer ID   Age  Gender Item Purchased     Category  \
# 0               1   NaN    Male         Blouse     Clothing
# 1               2   NaN    Male        Sweater     Clothing
# 2               3   NaN    Male          Jeans     Clothing
# 3               4   NaN    Male        Sandals     Footwear
# 4               5   NaN    Male         Blouse     Clothing
# ...           ...   ...     ...            ...          ...
# 3895         3896  40.0  Female         Hoodie     Clothing
# 3896         3897  52.0  Female       Backpack  Accessories
# 3897         3898  46.0  Female           Belt  Accessories
# 3898         3899  44.0  Female          Shoes     Footwear
# 3899         3900  52.0  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                       NaN       Kentucky    L       Gray  Winter
# 1                       NaN          Maine    L     Maroon  Winter
# ...

# %%
df.shape
# Out:
# (3900, 19)

# %%
df.head() # represents top 5 rows
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1  NaN   Male         Blouse  Clothing                    NaN
# 1            2  NaN   Male        Sweater  Clothing                    NaN
# 2            3  NaN   Male          Jeans  Clothing                    NaN
# 3            4  NaN   Male        Sandals  Footwear                   90.0
# 4            5  NaN   Male         Blouse  Clothing                    NaN
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            NaN                 yep
# 1          Maine    L     Maroon  Winter            NaN                 Yes
# 2  Massachusetts    S     Maroon  Spring            NaN                 Yes
# 3   Rhode Island    M     Maroon  Spring            NaN                 Yes
# 4         Oregon    M  Turquoise  Spring            NaN                  Yo
#
# ...

# %%
df.info()   # gives info about datatypes , no of rows etc
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3269 non-null   float64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3285 non-null   float64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3246 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %%
pd.isnull(df)  # gives true and false values ...jahan jahan false hai no null value
# Out:
#       Customer ID    Age  Gender  Item Purchased  Category  \
# 0           False   True   False           False     False
# 1           False   True   False           False     False
# 2           False   True   False           False     False
# 3           False   True   False           False     False
# 4           False   True   False           False     False
# ...           ...    ...     ...             ...       ...
# 3895        False  False   False           False     False
# 3896        False  False   False           False     False
# 3897        False  False   False           False     False
# 3898        False  False   False           False     False
# 3899        False  False   False           False     False
#
#       Purchase Amount (USD)  Location   Size  Color  Season  Review Rating  \
# 0                      True     False  False  False   False           True
# 1                      True     False  False  False   False           True
# ...

# %%
pd.isnull(df).sum()  # sum of null values
# Out:
# Customer ID                   0
# Age                         631
# Gender                        0
# Item Purchased                0
# Category                      0
# Purchase Amount (USD)       615
# Location                      0
# Size                          0
# Color                         0
# Season                        0
# Review Rating               654
# Subscription Status           0
# Payment Method                0
# Shipping Type                 0
# Discount Applied              0
# Promo Code Used               0
# Previous Purchases            0
# Preferred Payment Method      0
# Frequency of Purchases        0
# dtype: int64

# %%
df.shape  # to see the no of rows and columns
# Out:
# (3900, 19)

# %%
df.dropna(inplace=True)   # to drop null values

# %%
df.shape  # to see the no of rows and columns
# Out:
# (2677, 19)

# %%
df['Age']=df['Age'].astype('int')     # to change data types

# %%
df['Age'].dtypes    # to see the changed data types
# Out:
# dtype('int32')

# %%
df.columns     # to represent column names
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  2677.000000  2677.000000            2677.000000    2677.000000
# mean   2194.471423    43.821068              59.639148       3.744864
# std     980.054751    15.185122              23.782486       0.718999
# min      88.000000    18.000000              20.000000       2.500000
# 25%    1343.000000    31.000000              38.000000       3.100000
# 50%    2186.000000    44.000000              60.000000       3.700000
# 75%    3041.000000    57.000000              81.000000       4.400000
# max    3899.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         2677.000000
# mean            25.241315
# std             14.444447
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
ax=sns.countplot(x='Gender',data=df)
for bars in ax.containers:ax.bar_label(bars)      #for plotting the values

# %%
ax=sns.countplot(x='Payment Method',data=df)
for bars in ax.containers:ax.bar_label(bars)      #for plotting the values

# %%
ax=sns.countplot(x='Age',data=df)
for bars in ax.containers:ax.bar_label(bars)      #for plotting the values

# %%
sns.countplot(data=df,x='Age',hue='Gender')       #represents total ratio of males and females in a perticular agr group
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
df.hist(figsize=(15,10), bins=40)
plt.show()

# %% [markdown]
# # CHILD CARE COST: https://www.kaggle.com/datasets/sujaykapadnis/childcare-costs

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('childcare_costs.csv')

# %%
df
# Out:
#        county_fips_code  study_year  unr_16  funr_16  munr_16  unr_20to64  \
# 0                  1001        2008    5.42     4.41     6.32         4.6
# 1                  1001        2009    5.93     5.72     6.11         4.8
# 2                  1001        2010    6.21     5.57     6.78         5.1
# 3                  1001        2011    7.55     8.13     7.03         6.2
# 4                  1001        2012    8.60     8.88     8.29         6.7
# ...                 ...         ...     ...      ...      ...         ...
# 28044             48053        2014    6.20     5.99     6.29         5.6
# 28045             48053        2015    5.07     5.21     4.96         4.7
# 28046             48053        2016    4.57     3.36     5.63         4.2
# 28047             48053        2017    4.25     3.77     4.67         4.2
# 28048             48053        2018    4.51     4.34     4.66         4.5
#
#        funr_20to64  munr_20to64  flfpr_20to64  flfpr_20to64_under6  ...  \
# ...

# %%
df.shape
# Out:
# (28049, 61)

# %%
df.head()
# Out:
#    county_fips_code  study_year  unr_16  funr_16  munr_16  unr_20to64  \
# 0              1001        2008    5.42     4.41     6.32         4.6
# 1              1001        2009    5.93     5.72     6.11         4.8
# 2              1001        2010    6.21     5.57     6.78         5.1
# 3              1001        2011    7.55     8.13     7.03         6.2
# 4              1001        2012    8.60     8.88     8.29         6.7
#
#    funr_20to64  munr_20to64  flfpr_20to64  flfpr_20to64_under6  ...  memp_p  \
# 0          3.5          5.6          68.9                 66.9  ...   21.55
# 1          4.6          5.0          70.8                 63.7  ...   21.96
# 2          4.6          5.6          71.3                 67.0  ...   21.28
# 3          6.3          6.1          70.2                 66.5  ...   22.80
# 4          6.4          7.0          70.6                 67.1  ...   22.88
#
#    femp_p   mcsa  mfccsa  mc_infant  mc_toddler  mc_preschool  mfcc_infant  \
# ...

# %%
df.tail()
# Out:
#        county_fips_code  study_year  unr_16  funr_16  munr_16  unr_20to64  \
# 28044             48053        2014    6.20     5.99     6.29         5.6
# 28045             48053        2015    5.07     5.21     4.96         4.7
# 28046             48053        2016    4.57     3.36     5.63         4.2
# 28047             48053        2017    4.25     3.77     4.67         4.2
# 28048             48053        2018    4.51     4.34     4.66         4.5
#
#        funr_20to64  munr_20to64  flfpr_20to64  flfpr_20to64_under6  ...  \
# 28044          5.9          5.4          65.7                 60.3  ...
# 28045          5.2          4.3          65.5                 80.0  ...
# 28046          3.2          5.1          69.9                 95.9  ...
# 28047          3.4          4.8          68.8                 75.5  ...
# 28048          4.3          4.8          68.9                 77.1  ...
#
#        memp_p  femp_p    mcsa  mfccsa  mc_infant  mc_toddler  mc_preschool  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28049 entries, 0 to 28048
# Data columns (total 61 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   county_fips_code           28049 non-null  int64
#  1   study_year                 28049 non-null  int64
#  2   unr_16                     28049 non-null  float64
#  3   funr_16                    28049 non-null  float64
#  4   munr_16                    28049 non-null  float64
#  5   unr_20to64                 28049 non-null  float64
#  6   funr_20to64                28049 non-null  float64
#  7   munr_20to64                28049 non-null  float64
#  8   flfpr_20to64               28049 non-null  float64
#  9   flfpr_20to64_under6        28049 non-null  float64
#  10  flfpr_20to64_6to17         28049 non-null  float64
#  11  flfpr_20to64_under6_6to17  28049 non-null  float64
#  12  mlfpr_20to64               28049 non-null  float64
# ...

# %%
pd.isnull(df)
# Out:
#        county_fips_code  study_year  unr_16  funr_16  munr_16  unr_20to64  \
# 0                 False       False   False    False    False       False
# 1                 False       False   False    False    False       False
# 2                 False       False   False    False    False       False
# 3                 False       False   False    False    False       False
# 4                 False       False   False    False    False       False
# ...                 ...         ...     ...      ...      ...         ...
# 28044             False       False   False    False    False       False
# 28045             False       False   False    False    False       False
# 28046             False       False   False    False    False       False
# 28047             False       False   False    False    False       False
# 28048             False       False   False    False    False       False
#
#        funr_20to64  munr_20to64  flfpr_20to64  flfpr_20to64_under6  ...  \
# ...

# %%
pd.isnull(df).sum
# Out:
# <bound method DataFrame.sum of        county_fips_code  study_year  unr_16  funr_16  munr_16  unr_20to64  \
# 0                 False       False   False    False    False       False
# 1                 False       False   False    False    False       False
# 2                 False       False   False    False    False       False
# 3                 False       False   False    False    False       False
# 4                 False       False   False    False    False       False
# ...                 ...         ...     ...      ...      ...         ...
# 28044             False       False   False    False    False       False
# 28045             False       False   False    False    False       False
# 28046             False       False   False    False    False       False
# 28047             False       False   False    False    False       False
# 28048             False       False   False    False    False       False
#
# ...

# %%
df.shape
# Out:
# (28049, 61)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (17336, 61)

# %%
df['households']=df['households'].astype('float')

# %%
df['households'].dtypes
# Out:
# dtype('float64')

# %%
df.columns
# Out:
# Index(['county_fips_code', 'study_year', 'unr_16', 'funr_16', 'munr_16',
#        'unr_20to64', 'funr_20to64', 'munr_20to64', 'flfpr_20to64',
#        'flfpr_20to64_under6', 'flfpr_20to64_6to17',
#        'flfpr_20to64_under6_6to17', 'mlfpr_20to64', 'pr_f', 'pr_p', 'mhi_2018',
#        'me_2018', 'fme_2018', 'mme_2018', 'total_pop', 'one_race',
#        'one_race_w', 'one_race_b', 'one_race_i', 'one_race_a', 'one_race_h',
#        'one_race_other', 'two_races', 'hispanic', 'households',
#        'h_under6_both_work', 'h_under6_f_work', 'h_under6_m_work',
#        'h_under6_single_m', 'h_6to17_both_work', 'h_6to17_fwork',
#        'h_6to17_mwork', 'h_6to17_single_m', 'emp_m', 'memp_m', 'femp_m',
#        'emp_service', 'memp_service', 'femp_service', 'emp_sales',
#        'memp_sales', 'femp_sales', 'emp_n', 'memp_n', 'femp_n', 'emp_p',
#        'memp_p', 'femp_p', 'mcsa', 'mfccsa', 'mc_infant', 'mc_toddler',
#        'mc_preschool', 'mfcc_infant', 'mfcc_toddler', 'mfcc_preschool'],
# ...

# %%
df.describe()
# Out:
#        county_fips_code    study_year        unr_16       funr_16  \
# count      17336.000000  17336.000000  17336.000000  17336.000000
# mean       27139.070028   2013.445662      7.792641      7.335675
# std        13351.290794      3.108543      3.752096      3.776152
# min         1001.000000   2008.000000      0.000000      0.000000
# 25%        17202.500000   2011.000000      5.300000      4.830000
# 50%        26139.000000   2014.000000      7.450000      6.950000
# 75%        39155.000000   2016.000000      9.840000      9.330000
# max        48053.000000   2018.000000     30.930000     38.240000
#
#             munr_16    unr_20to64   funr_20to64   munr_20to64  flfpr_20to64  \
# count  17336.000000  17336.000000  17336.000000  17336.000000  17336.000000
# mean       8.207858      7.223853      6.779399      7.629210     69.907257
# std        4.206556      3.646880      3.671383      4.155952      7.777348
# ...

# %%
df.columns
# Out:
# Index(['county_fips_code', 'study_year', 'unr_16', 'funr_16', 'munr_16',
#        'unr_20to64', 'funr_20to64', 'munr_20to64', 'flfpr_20to64',
#        'flfpr_20to64_under6', 'flfpr_20to64_6to17',
#        'flfpr_20to64_under6_6to17', 'mlfpr_20to64', 'pr_f', 'pr_p', 'mhi_2018',
#        'me_2018', 'fme_2018', 'mme_2018', 'total_pop', 'one_race',
#        'one_race_w', 'one_race_b', 'one_race_i', 'one_race_a', 'one_race_h',
#        'one_race_other', 'two_races', 'hispanic', 'households',
#        'h_under6_both_work', 'h_under6_f_work', 'h_under6_m_work',
#        'h_under6_single_m', 'h_6to17_both_work', 'h_6to17_fwork',
#        'h_6to17_mwork', 'h_6to17_single_m', 'emp_m', 'memp_m', 'femp_m',
#        'emp_service', 'memp_service', 'femp_service', 'emp_sales',
#        'memp_sales', 'femp_sales', 'emp_n', 'memp_n', 'femp_n', 'emp_p',
#        'memp_p', 'femp_p', 'mcsa', 'mfccsa', 'mc_infant', 'mc_toddler',
#        'mc_preschool', 'mfcc_infant', 'mfcc_toddler', 'mfcc_preschool'],
# ...

# %%
ax = sns.countplot(x = 'study_year',data=df)
for bars in ax.containers:ax.bar_label(bars)

# %%
ax = sns.countplot(x = 'one_race_w',data=df)
for bars in ax.containers:ax.bar_label(bars)

# %%
ax = sns.countplot(x = 'two_races',data=df)
for bars in ax.containers:ax.bar_label(bars)

# %%
sns.countplot( data=df, x='funr_16', hue='munr_16')
# Out:
# <Axes: xlabel='funr_16', ylabel='count'>

# %%
df.hist(figsize=(15,10), bins=40)
plt.show()

# %%
correlation_matrix = df.corr()
correlation_matrix
# Out:
#                   county_fips_code  study_year    unr_16   funr_16   munr_16  \
# county_fips_code          1.000000    0.009673 -0.160246 -0.163488 -0.140172
# study_year                0.009673    1.000000 -0.090426 -0.078023 -0.090250
# unr_16                   -0.160246   -0.090426  1.000000  0.921450  0.952883
# funr_16                  -0.163488   -0.078023  0.921450  1.000000  0.761526
# munr_16                  -0.140172   -0.090250  0.952883  0.761526  1.000000
# ...                            ...         ...       ...       ...       ...
# mc_toddler               -0.065827    0.193428 -0.096051 -0.124477 -0.062436
# mc_preschool             -0.047032    0.195253 -0.085377 -0.111316 -0.055137
# mfcc_infant              -0.087471    0.168548 -0.052810 -0.073842 -0.030426
# mfcc_toddler             -0.086162    0.185324 -0.059613 -0.082751 -0.034757
# mfcc_preschool           -0.084770    0.176212 -0.067096 -0.090022 -0.041696
#
# ...

# %%
plt.figure(figsize=(70, 40))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Heatmap Matrix')
plt.show()
